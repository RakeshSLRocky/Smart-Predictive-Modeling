# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
# Read the file into a pandas dataframe
df = pd.read_excel('House_Rent_Train.xlsx')
df.head(2)
# Out:
#                                  id  type   locality      activation_date  \
# 0  ff8081815733a243015733b2876600a6  BHK2        NaN     21-04-2018 14:44
# 1  ff8081815ee25e15015ee50004da2acd  BHK2  Bellandur  2017-09-10 12:48:00
#
#     latitude  longitude lease_type  gym  lift  swimming_pool  ...  bathroom  \
# 0  12.934471  77.634471     FAMILY    1     1              1  ...       2.0
# 1  12.929557  77.672280     ANYONE    0     1              0  ...       2.0
#
#   facing cup_board  floor  total_floor  \
# 0      E       2.0    6.0         12.0
# 1     NE       2.0    3.0          4.0
#
#                                            amenities water_supply  \
# 0  {"LIFT":true,"GYM":true,"INTERNET":true,"AC":f...    CORP_BORE
# 1  {"LIFT":true,"GYM":false,"INTERNET":false,"AC"...  CORPORATION
#
#    building_type  balconies     rent
# 0             AP        2.0  40000.0
# 1             AP        2.0  22000.0
#
# [2 rows x 25 columns]

# %%
df.shape
# Out:
# (20555, 25)

# %%
df.isnull().sum()
# Out:
# id                   0
# type                27
# locality           160
# activation_date     23
# latitude            23
# longitude           23
# lease_type          23
# gym                  0
# lift                 0
# swimming_pool        0
# negotiable           0
# furnishing           0
# parking              0
# property_size        0
# property_age        23
# bathroom            23
# facing              23
# cup_board           23
# floor               23
# total_floor         23
# amenities           23
# water_supply        23
# building_type       23
# balconies           23
# rent                23
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# id                 0
# type               0
# locality           0
# activation_date    0
# latitude           0
# longitude          0
# lease_type         0
# gym                0
# lift               0
# swimming_pool      0
# negotiable         0
# furnishing         0
# parking            0
# property_size      0
# property_age       0
# bathroom           0
# facing             0
# cup_board          0
# floor              0
# total_floor        0
# amenities          0
# water_supply       0
# building_type      0
# balconies          0
# rent               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 20

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
df.type.value_counts()
# Out:
# BHK2        11583
# BHK3         4354
# BHK1         3576
# RK1           550
# BHK4          232
# BHK4PLUS       30
# bhk2           16
# bhk3           12
# 1BHK1           4
# Name: type, dtype: int64

# %%
df.lease_type.value_counts()
# Out:
# FAMILY      10101
# ANYONE       9614
# BACHELOR      584
# COMPANY        58
# Name: lease_type, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'type', 'locality', 'activation_date', 'latitude', 'longitude',
#        'lease_type', 'gym', 'lift', 'swimming_pool', 'negotiable',
#        'furnishing', 'parking', 'property_size', 'property_age', 'bathroom',
#        'facing', 'cup_board', 'floor', 'total_floor', 'amenities',
#        'water_supply', 'building_type', 'balconies', 'rent'],
#       dtype='object')

# %%
print(df['type'].unique())
print(df['locality'].unique())
print(df['lease_type'].unique())
print(df['furnishing'].unique())
print(df['parking'].unique())
print(df['building_type'].unique())
print(df['water_supply'].unique())
print(df['facing'].unique())
# Out:
# ['BHK2' 'BHK3' 'BHK1' 'RK1' 'BHK4' 'BHK4PLUS' '1BHK1' 'bhk2' 'bhk3']
# ['Bellandur' 'Thiruvanmiyur' 'Attiguppe' ...
#  'Reliance Fresh, Whitefield Main Road, Industrial Area, Whitefield'
#  'Koramangala 4th block'
#  'Mahadevapura bus stop, Mahadevapura, Bengaluru, Karnataka, India']
# ['ANYONE' 'FAMILY' 'BACHELOR' 'COMPANY']
# ['SEMI_FURNISHED' 'FULLY_FURNISHED' 'NOT_FURNISHED']
# ['BOTH' 'TWO_WHEELER' 'NONE' 'FOUR_WHEELER']
# ['AP' 'IH' 'IF' 'GC']
# ['CORPORATION' 'CORP_BORE' 'BOREWELL']
# ['NE' 'E' 'S' 'N' 'SE' 'W' 'NW' 'SW']

# %%
mapping_dict = {'bhk2': 'BHK2','bhk3': 'BHK3','1BHK1': 'BHK1'}
df['type'] = df['type'].replace(mapping_dict)

# %%
print(df['type'].unique())
print(df['locality'].unique())
print(df['lease_type'].unique())
print(df['furnishing'].unique())
print(df['parking'].unique())
print(df['building_type'].unique())
print(df['water_supply'].unique())
print(df['facing'].unique())
# Out:
# ['BHK2' 'BHK3' 'BHK1' 'RK1' 'BHK4' 'BHK4PLUS']
# ['Bellandur' 'Thiruvanmiyur' 'Attiguppe' ...
#  'Reliance Fresh, Whitefield Main Road, Industrial Area, Whitefield'
#  'Koramangala 4th block'
#  'Mahadevapura bus stop, Mahadevapura, Bengaluru, Karnataka, India']
# ['ANYONE' 'FAMILY' 'BACHELOR' 'COMPANY']
# ['SEMI_FURNISHED' 'FULLY_FURNISHED' 'NOT_FURNISHED']
# ['BOTH' 'TWO_WHEELER' 'NONE' 'FOUR_WHEELER']
# ['AP' 'IH' 'IF' 'GC']
# ['CORPORATION' 'CORP_BORE' 'BOREWELL']
# ['NE' 'E' 'S' 'N' 'SE' 'W' 'NW' 'SW']

# %%
df.type.value_counts()
# Out:
# BHK2        11599
# BHK3         4366
# BHK1         3580
# RK1           550
# BHK4          232
# BHK4PLUS       30
# Name: type, dtype: int64

# %%
df.dtypes
# Out:
# id                  object
# type                object
# locality            object
# activation_date     object
# latitude           float64
# longitude          float64
# lease_type          object
# gym                  int64
# lift                 int64
# swimming_pool        int64
# negotiable           int64
# furnishing          object
# parking             object
# property_size        int64
# property_age       float64
# bathroom           float64
# facing              object
# cup_board          float64
# floor              float64
# total_floor        float64
# amenities           object
# water_supply        object
# building_type       object
# balconies          float64
# rent               float64
# dtype: object

# %%
columns_to_convert = ['property_age', 'bathroom', 'cup_board', 'floor', 'total_floor', 'balconies', 'rent']

# Convert specified columns to int64
df[columns_to_convert] = df[columns_to_convert].astype('int64')

# %%
df.dtypes
# Out:
# id                  object
# type                object
# locality            object
# activation_date     object
# latitude           float64
# longitude          float64
# lease_type          object
# gym                  int64
# lift                 int64
# swimming_pool        int64
# negotiable           int64
# furnishing          object
# parking             object
# property_size        int64
# property_age         int64
# bathroom             int64
# facing              object
# cup_board            int64
# floor                int64
# total_floor          int64
# amenities           object
# water_supply        object
# building_type       object
# balconies            int64
# rent                 int64
# dtype: object

# %%
df.describe()
# Out:
#            latitude     longitude           gym          lift  swimming_pool  \
# count  20357.000000  20357.000000  20357.000000  20357.000000   20357.000000
# mean      12.945749     77.637238      0.226359      0.361006       0.174633
# std        0.029582      0.110805      0.418485      0.480304       0.379662
# min       12.900004     77.500072      0.000000      0.000000       0.000000
# 25%       12.918242     77.571891      0.000000      0.000000       0.000000
# 50%       12.943792     77.633367      0.000000      0.000000       0.000000
# 75%       12.970914     77.695707      0.000000      1.000000       0.000000
# max       12.999999     80.266346      1.000000      1.000000       1.000000
#
#          negotiable  property_size  property_age      bathroom     cup_board  \
# count  20357.000000   20357.000000  20357.000000  20357.000000  20357.000000
# mean       0.711401    1061.571253      5.776244      1.857887      4.570222
# ...

# %%
q3 = df.property_size.quantile(0.75)
q1=df.property_size.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(df.property_size), 'Min size :', min(df.property_size))
df.property_size=df.property_size.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 2150.0 lower_threshold: -170.0
# Max size : 50000 Min size : 1

# %%
q3 = df.property_age.quantile(0.75)
q1=df.property_age.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(df.property_age), 'Min size :', min(df.property_age))
df.property_age=df.property_age.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 23.5 lower_threshold: -12.5
# Max size : 400 Min size : -1

# %%
q3 = df.bathroom.quantile(0.75)
q1=df.bathroom.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(df.bathroom), 'Min size :', min(df.bathroom))
df.bathroom=df.bathroom.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 3.5 lower_threshold: -0.5
# Max size : 21 Min size : 1

# %%
q3 = df.cup_board.quantile(0.75)
q1=df.cup_board.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(df.cup_board), 'Min size :', min(df.cup_board))
df.cup_board=df.cup_board.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 6.0 lower_threshold: -2.0
# Max size : 48026 Min size : 0

# %%
q3 = df.floor.quantile(0.75)
q1=df.floor.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(df.floor), 'Min size :', min(df.floor))
df.floor=df.floor.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 3.5 lower_threshold: -0.5
# Max size : 25 Min size : 0

# %%
q3 = df.total_floor.quantile(0.75)
q1=df.total_floor.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(df.total_floor), 'Min size :', min(df.total_floor))
df.total_floor=df.total_floor.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 7.0 lower_threshold: -1.0
# Max size : 26 Min size : 0

# %%
q3 = df.balconies.quantile(0.75)
q1=df.balconies.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(df.balconies), 'Min size :', min(df.balconies))
df.balconies=df.balconies.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 5.0 lower_threshold: -3.0
# Max size : 13 Min size : 0

# %%
df.describe()
# Out:
#            latitude     longitude           gym          lift  swimming_pool  \
# count  20357.000000  20357.000000  20357.000000  20357.000000   20357.000000
# mean      12.945749     77.637238      0.226359      0.361006       0.174633
# std        0.029582      0.110805      0.418485      0.480304       0.379662
# min       12.900004     77.500072      0.000000      0.000000       0.000000
# 25%       12.918242     77.571891      0.000000      0.000000       0.000000
# 50%       12.943792     77.633367      0.000000      0.000000       0.000000
# 75%       12.970914     77.695707      0.000000      1.000000       0.000000
# max       12.999999     80.266346      1.000000      1.000000       1.000000
#
#          negotiable  property_size  property_age      bathroom     cup_board  \
# count  20357.000000   20357.000000  20357.000000  20357.000000  20357.000000
# mean       0.711401    1047.785676      5.657341      1.847055      2.161664
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.histplot(df.gym)
plt.subplot(1,2,2)
sns.histplot(df.lift,color = 'darkblue')
plt.tight_layout()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.histplot(df.swimming_pool)
plt.subplot(1,2,2)
sns.histplot(df.negotiable,color = 'darkblue')
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.histplot(df.property_size)
plt.subplot(1,2,2)
sns.histplot(df.property_age,color = 'darkblue')
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.histplot(df.bathroom)
plt.subplot(1,2,2)
sns.histplot(df.cup_board,color = 'darkblue')
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
sns.histplot(df.floor)
plt.subplot(1,3,2)
sns.histplot(df.total_floor,color = 'darkblue')
plt.subplot(1,3,3)
sns.histplot(df.balconies)
plt.tight_layout()

# %%
plt.figure(figsize=(10,6))
df_source = df.type.value_counts()
df_source = df_source.reset_index()
plt.pie(df_source['type'],labels=df_source['index'],autopct='%1.1f%%')
plt.title('Percent distribution of  type')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(10,6))
df_source = df.lease_type.value_counts()
df_source = df_source.reset_index()
plt.pie(df_source['lease_type'],labels=df_source['index'],autopct='%1.1f%%')
plt.title('Percent distribution of  lease_type')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(10,6))
df_source = df.furnishing.value_counts()
df_source = df_source.reset_index()
plt.pie(df_source['furnishing'],labels=df_source['index'],autopct='%1.1f%%')
plt.title('Percent distribution of  furnishing')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(10,6))
df_source = df.parking.value_counts()
df_source = df_source.reset_index()
plt.pie(df_source['parking'],labels=df_source['index'],autopct='%1.1f%%')
plt.title('Percent distribution of  parking')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(10,6))
df_source = df.facing.value_counts()
df_source = df_source.reset_index()
plt.pie(df_source['facing'],labels=df_source['index'],autopct='%1.1f%%')
plt.title('Percent distribution of  facing')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(10,6))
df_source = df.water_supply.value_counts()
df_source = df_source.reset_index()
plt.pie(df_source['water_supply'],labels=df_source['index'],autopct='%1.1f%%')
plt.title('Percent distribution of  water_supply')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(10,6))
df_source = df.building_type.value_counts()
df_source = df_source.reset_index()
plt.pie(df_source['building_type'],labels=df_source['index'],autopct='%1.1f%%')
plt.title('Percent distribution of  building_type')
plt.axis('equal')
plt.show()

# %%
sns.barplot(x='building_type',y='rent',data=df,order=df.groupby('building_type')['rent'].mean().reset_index().sort_values('rent')['building_type'])
plt.xticks(rotation=75)
plt.title('building_type vs rent')
plt.show()
plt.tight_layout()

# %% [markdown]
# Label encoding
#
# {'IF':0, 'IH':1, 'AP':2, 'GC':3}

# %%
sns.barplot(x='water_supply',y='rent',data=df,order=df.groupby('water_supply')['rent'].mean().reset_index().sort_values('rent')['water_supply'])
plt.xticks(rotation=75)
plt.title('water_supply vs rent')
plt.show()
plt.tight_layout()

# %% [markdown]
# Label Encoding
#
# {'CORPORATION':0, 'CORP_BORE':1, 'BOREWELL':2}

# %%
sns.barplot(x='facing',y='rent',data=df,order=df.groupby('facing')['rent'].mean().reset_index().sort_values('rent')['facing'])
plt.xticks(rotation=75)
plt.title('facing vs rent')
plt.show()
plt.tight_layout()

# %% [markdown]
# Label Encoding
#
# {'N':0, 'S':1, 'E':2, 'W':3, 'NE':4, 'NW':5, 'SE':6, 'SW':7}

# %%
sns.barplot(x='parking',y='rent',data=df,order=df.groupby('parking')['rent'].mean().reset_index().sort_values('rent')['parking'])
plt.xticks(rotation=75)
plt.title('parking vs rent')
plt.show()
plt.tight_layout()

# %% [markdown]
# Label Encoding
#
# {'TWO_WHEELER':0, 'NONE':1, 'FOUR_WHEELER':2, 'BOTH':3}

# %%
sns.barplot(x='furnishing',y='rent',data=df,order=df.groupby('furnishing')['rent'].mean().reset_index().sort_values('rent')['furnishing'])
plt.xticks(rotation=75)
plt.title('furnishing vs rent')
plt.show()
plt.tight_layout()

# %% [markdown]
# Label Encoding
#
# {'NOT_FURNISHED':0, 'SEMI_FURNISHED':1, 'FULLY_FURNISHED':2}

# %%
sns.barplot(x='lease_type',y='rent',data=df,order=df.groupby('lease_type')['rent'].mean().reset_index().sort_values('rent')['lease_type'])
plt.xticks(rotation=75)
plt.title('lease_type vs rent')
plt.show()
plt.tight_layout()

# %% [markdown]
# Label Encoding
#
# {'BACHELOR':0, 'ANYONE':1, 'FMAILY':2, 'COMPANY':3}

# %%
sns.barplot(x='type',y='rent',data=df,order=df.groupby('type')['rent'].mean().reset_index().sort_values('rent')['type'])
plt.xticks(rotation=75)
plt.title('type vs rent')
plt.show()
plt.tight_layout()

# %% [markdown]
# Label Encoding
#
# {'RK1':0, 'BHK1':1, 'BHK2':2, 'BHK3':3, 'BHK4':4, 'BHK4PLUS':5}

# %%
gym_conversion_rates = df.groupby('gym')['rent'].mean()
sorted_gym = gym_conversion_rates.reset_index().sort_values('gym')['gym']
plt.figure(figsize=(18,6))
sns.barplot(x='gym', y='rent',data = df, order = sorted_gym)
# Out:
# <AxesSubplot:xlabel='gym', ylabel='rent'>

# %%
lift_conversion_rates = df.groupby('lift')['rent'].mean()
sorted_lift = lift_conversion_rates.reset_index().sort_values('lift')['lift']
plt.figure(figsize=(18,6))
sns.barplot(x='lift', y='rent',data = df, order = sorted_lift)
# Out:
# <AxesSubplot:xlabel='lift', ylabel='rent'>

# %%
swimming_pool_conversion_rates = df.groupby('swimming_pool')['rent'].mean()
sorted_swimming_pool = swimming_pool_conversion_rates.reset_index().sort_values('swimming_pool')['swimming_pool']
plt.figure(figsize=(18,6))
sns.barplot(x='swimming_pool', y='rent',data = df, order = sorted_swimming_pool)
# Out:
# <AxesSubplot:xlabel='swimming_pool', ylabel='rent'>

# %%
property_age_conversion_rates = df.groupby('property_age')['rent'].mean()
sorted_property_age = property_age_conversion_rates.reset_index().sort_values('property_age')['property_age']
plt.figure(figsize=(18,6))
sns.barplot(x='property_age', y='rent',data = df, order = sorted_property_age)
# Out:
# <AxesSubplot:xlabel='property_age', ylabel='rent'>

# %%
bathroom_conversion_rates = df.groupby('bathroom')['rent'].mean()
sorted_bathroom = bathroom_conversion_rates.reset_index().sort_values('bathroom')['bathroom']
plt.figure(figsize=(18,6))
sns.barplot(x='bathroom', y='rent',data = df, order = sorted_bathroom)
# Out:
# <AxesSubplot:xlabel='bathroom', ylabel='rent'>

# %%
cup_board_conversion_rates = df.groupby('cup_board')['rent'].mean()
sorted_cup_board = cup_board_conversion_rates.reset_index().sort_values('cup_board')['cup_board']
plt.figure(figsize=(18,6))
sns.barplot(x='cup_board', y='rent',data = df, order = sorted_cup_board)
# Out:
# <AxesSubplot:xlabel='cup_board', ylabel='rent'>

# %%
floor_conversion_rates = df.groupby('floor')['rent'].mean()
sorted_floor = floor_conversion_rates.reset_index().sort_values('floor')['floor']
plt.figure(figsize=(18,6))
sns.barplot(x='floor', y='rent',data = df, order = sorted_floor)
# Out:
# <AxesSubplot:xlabel='floor', ylabel='rent'>

# %%
total_floor_conversion_rates = df.groupby('total_floor')['rent'].mean()
sorted_total_floor = total_floor_conversion_rates.reset_index().sort_values('total_floor')['total_floor']
plt.figure(figsize=(18,6))
sns.barplot(x='total_floor', y='rent',data = df, order = sorted_total_floor)
# Out:
# <AxesSubplot:xlabel='total_floor', ylabel='rent'>

# %%
balconies_conversion_rates = df.groupby('balconies')['rent'].mean()
sorted_balconies = balconies_conversion_rates.reset_index().sort_values('balconies')['balconies']
plt.figure(figsize=(18,6))
sns.barplot(x='balconies', y='rent',data = df, order = sorted_balconies)
# Out:
# <AxesSubplot:xlabel='balconies', ylabel='rent'>

# %%
df.to_csv("data_for_streamlit.csv", index = False)

# %%
df.head()
# Out:
#                                  id  type              locality  \
# 1  ff8081815ee25e15015ee50004da2acd  BHK2             Bellandur
# 2  ff80818163f29c9e0163f46770b873e7  BHK3         Thiruvanmiyur
# 3  ff80818164b68a700164b74b1b247a1d  BHK1             Attiguppe
# 4  ff80818163b1faf00163b4b9b8a163b1  BHK3             Kodihalli
# 5  ff8081815f48e4aa015f4dd1a9c6696b  BHK1  Seetharampalya,Hoodi
#
#        activation_date   latitude  longitude lease_type  gym  lift  \
# 1  2017-09-10 12:48:00  12.929557  77.672280     ANYONE    0     1
# 2  2018-12-06 22:02:00  12.982870  80.262012     FAMILY    0     1
# 3     20-07-2018 16:22  12.955991  77.531634     FAMILY    0     0
# 4     31-05-2018 17:41  12.963903  77.649446     FAMILY    0     0
# 5     24-10-2017 18:29  12.986196  77.718314     FAMILY    1     1
#
#    swimming_pool  ...  bathroom facing cup_board  floor  total_floor  \
# 1              0  ...       2.0     NE       2.0    3.0          4.0
# ...

# %% [markdown]
# # LABEL ENCODING

# %%
df['building_type']=df['building_type'].map({'IF':0, 'IH':1, 'AP':2, 'GC':3})
df['water_supply']=df['water_supply'].map({'CORPORATION':0, 'CORP_BORE':1, 'BOREWELL':2})
df['facing']=df['facing'].map({'N':0, 'S':1, 'E':2, 'W':3, 'NE':4, 'NW':5, 'SE':6, 'SW':7})
df['parking']=df['parking'].map({'TWO_WHEELER':0, 'NONE':1, 'FOUR_WHEELER':2, 'BOTH':3})
df['furnishing']=df['furnishing'].map({'NOT_FURNISHED':0, 'SEMI_FURNISHED':1, 'FULLY_FURNISHED':2})
df['lease_type']=df['lease_type'].map({'BACHELOR':0, 'ANYONE':1, 'FAMILY':2, 'COMPANY':3})
df['type']=df['type'].map({'RK1':0, 'BHK1':1, 'BHK2':2, 'BHK3':3, 'BHK4':4, 'BHK4PLUS':5})
df.head()
# Out:
#                                  id  type              locality  \
# 1  ff8081815ee25e15015ee50004da2acd     2             Bellandur
# 2  ff80818163f29c9e0163f46770b873e7     3         Thiruvanmiyur
# 3  ff80818164b68a700164b74b1b247a1d     1             Attiguppe
# 4  ff80818163b1faf00163b4b9b8a163b1     3             Kodihalli
# 5  ff8081815f48e4aa015f4dd1a9c6696b     1  Seetharampalya,Hoodi
#
#        activation_date   latitude  longitude  lease_type  gym  lift  \
# 1  2017-09-10 12:48:00  12.929557  77.672280           1    0     1
# 2  2018-12-06 22:02:00  12.982870  80.262012           2    0     1
# 3     20-07-2018 16:22  12.955991  77.531634           2    0     0
# 4     31-05-2018 17:41  12.963903  77.649446           2    0     0
# 5     24-10-2017 18:29  12.986196  77.718314           2    1     1
#
#    swimming_pool  ...  bathroom  facing  cup_board  floor  total_floor  \
# 1              0  ...       2.0       4        2.0    3.0          4.0
# ...

# %%
df = df.drop(columns=['amenities'])

# %%
df.head()
# Out:
#                                  id  type              locality  \
# 1  ff8081815ee25e15015ee50004da2acd     2             Bellandur
# 2  ff80818163f29c9e0163f46770b873e7     3         Thiruvanmiyur
# 3  ff80818164b68a700164b74b1b247a1d     1             Attiguppe
# 4  ff80818163b1faf00163b4b9b8a163b1     3             Kodihalli
# 5  ff8081815f48e4aa015f4dd1a9c6696b     1  Seetharampalya,Hoodi
#
#        activation_date   latitude  longitude  lease_type  gym  lift  \
# 1  2017-09-10 12:48:00  12.929557  77.672280           1    0     1
# 2  2018-12-06 22:02:00  12.982870  80.262012           2    0     1
# 3     20-07-2018 16:22  12.955991  77.531634           2    0     0
# 4     31-05-2018 17:41  12.963903  77.649446           2    0     0
# 5     24-10-2017 18:29  12.986196  77.718314           2    1     1
#
#    swimming_pool  ...  property_age  bathroom  facing  cup_board  floor  \
# 1              0  ...           4.0       2.0       4        2.0    3.0
# ...

# %%
df = df.drop(columns=['id'])

# %%
df.head()
# Out:
#    type              locality      activation_date   latitude  longitude  \
# 1     2             Bellandur  2017-09-10 12:48:00  12.929557  77.672280
# 2     3         Thiruvanmiyur  2018-12-06 22:02:00  12.982870  80.262012
# 3     1             Attiguppe     20-07-2018 16:22  12.955991  77.531634
# 4     3             Kodihalli     31-05-2018 17:41  12.963903  77.649446
# 5     1  Seetharampalya,Hoodi     24-10-2017 18:29  12.986196  77.718314
#
#    lease_type  gym  lift  swimming_pool  negotiable  ...  property_age  \
# 1           1    0     1              0           1  ...           4.0
# 2           2    0     1              0           0  ...           6.0
# 3           2    0     0              0           1  ...           3.0
# 4           2    0     0              0           1  ...          15.0
# 5           2    1     1              1           1  ...           0.0
#
#    bathroom  facing  cup_board  floor  total_floor  water_supply  \
# ...

# %%
df.columns
# Out:
# Index(['type', 'locality', 'activation_date', 'latitude', 'longitude',
#        'lease_type', 'gym', 'lift', 'swimming_pool', 'negotiable',
#        'furnishing', 'parking', 'property_size', 'property_age', 'bathroom',
#        'facing', 'cup_board', 'floor', 'total_floor', 'water_supply',
#        'building_type', 'balconies', 'rent'],
#       dtype='object')

# %%
X = df[['type','lease_type', 'gym', 'lift', 'swimming_pool', 'negotiable',
       'furnishing', 'parking', 'property_size', 'property_age', 'bathroom','facing', 'cup_board', 'floor', 'total_floor', 'water_supply',
       'building_type', 'balconies']].values
y = df['rent'].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20, random_state = 7)

# %%
from sklearn.linear_model import LinearRegression #importing all the required functions
regressor = LinearRegression() # spredicted score = m * hours + c  
"Symtax : varName = ModelName(modelHyperParams)"
regressor.fit(X_train, y_train) #Learning happens - GD is done and we get the final values of m and c
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test) # given the features of the test dataset, it will give the final predictions
"Syntax : varName.predict(test_features)"
y_pred
# Out:
# array([30596.98369217, 33052.42260496,  8869.63510191, ...,
#        23104.44090522, 22308.02760864, 18512.00890385])

# %%
from sklearn import metrics
print('R2- SCORE:', metrics.r2_score(y_test,y_pred))
# Out:
# R2- SCORE: 0.6518607631281879

# %%
new_data = pd.read_excel('House_Rent_Test.xlsx')
new_data = new_data.drop(columns=['amenities', 'id'])

# %%
new_data = new_data.dropna()
new_data.isnull().sum()
new_data = new_data.drop_duplicates()
new_data.duplicated().sum()
# Out:
# 0

# %%
mapping_dict = {'bhk2': 'BHK2','bhk3': 'BHK3','1BHK1': 'BHK1'}
new_data['type'] = new_data['type'].replace(mapping_dict)
columns_to_convert = ['property_age', 'bathroom', 'cup_board', 'floor', 'total_floor', 'balconies']

# Convert specified columns to int64
new_data[columns_to_convert] = new_data[columns_to_convert].astype('int64')
q3 = new_data.property_size.quantile(0.75)
q1=new_data.property_size.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(new_data.property_size), 'Min size :', min(new_data.property_size))
new_data.property_size=new_data.property_size.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 2200.0 lower_threshold: -200.0
# Max size : 20000 Min size : 1

# %%
q3 = new_data.property_age.quantile(0.75)
q1=new_data.property_age.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(new_data.property_age), 'Min size :', min(new_data.property_age))
new_data.property_age=new_data.property_age.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 21.0 lower_threshold: -11.0
# Max size : 999 Min size : -1

# %%
q3 = new_data.bathroom.quantile(0.75)
q1=new_data.bathroom.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(new_data.bathroom), 'Min size :', min(new_data.bathroom))
new_data.bathroom=new_data.bathroom.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 3.5 lower_threshold: -0.5
# Max size : 34 Min size : 1

# %%
q3 = new_data.cup_board.quantile(0.75)
q1=new_data.cup_board.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(new_data.cup_board), 'Min size :', min(new_data.cup_board))
new_data.cup_board=new_data.cup_board.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 6.0 lower_threshold: -2.0
# Max size : 30 Min size : 0

# %%
q3 = new_data.floor.quantile(0.75)
q1=new_data.floor.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(new_data.floor), 'Min size :', min(new_data.floor))
new_data.floor=new_data.floor.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 6.0 lower_threshold: -2.0
# Max size : 21 Min size : 0

# %%
q3 = new_data.total_floor.quantile(0.75)
q1=new_data.total_floor.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(new_data.total_floor), 'Min size :', min(new_data.total_floor))
new_data.total_floor=new_data.total_floor.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 7.0 lower_threshold: -1.0
# Max size : 50 Min size : 0

# %%
q3 = new_data.balconies.quantile(0.75)
q1=new_data.balconies.quantile(0.25)
iqr=q3-q1
upper_threshold=q3+(1.5*iqr)
lower_threshold=q1-(1.5*iqr)
print("upper_threshold:", upper_threshold,"lower_threshold:", lower_threshold)
print('Max size :', max(new_data.balconies), 'Min size :', min(new_data.balconies))
new_data.balconies=new_data.balconies.clip(upper_threshold,lower_threshold)
# Out:
# upper_threshold: 5.0 lower_threshold: -3.0
# Max size : 22 Min size : 0

# %%
new_data['building_type']=new_data['building_type'].map({'IF':0, 'IH':1, 'AP':2, 'GC':3})
new_data['water_supply']=new_data['water_supply'].map({'CORPORATION':0, 'CORP_BORE':1, 'BOREWELL':2})
new_data['facing']=new_data['facing'].map({'N':0, 'S':1, 'E':2, 'W':3, 'NE':4, 'NW':5, 'SE':6, 'SW':7})
new_data['parking']=new_data['parking'].map({'TWO_WHEELER':0, 'NONE':1, 'FOUR_WHEELER':2, 'BOTH':3})
new_data['furnishing']=new_data['furnishing'].map({'NOT_FURNISHED':0, 'SEMI_FURNISHED':1, 'FULLY_FURNISHED':2})
new_data['lease_type']=new_data['lease_type'].map({'BACHELOR':0, 'ANYONE':1, 'FAMILY':2, 'COMPANY':3})
new_data['type']=new_data['type'].map({'RK1':0, 'BHK1':1, 'BHK2':2, 'BHK3':3, 'BHK4':4, 'BHK4PLUS':5})
new_data.head()
# Out:
#    type                       locality      activation_date   latitude  \
# 0     2                   Basavanagudi     22-08-2017 09:00  12.941603
# 1     2                   Rajaji Nagar     17-09-2017 16:33  12.998803
# 2     1              Jeevan Bima Nagar     14-04-2018 17:27  12.966467
# 3     1            Jayanagar 1st Block  2017-11-12 13:15:00  12.941533
# 4     3  Whitefield Hope Farm Junction  2017-11-07 16:44:00  12.971083
#
#    longitude  lease_type  gym  lift  swimming_pool  negotiable  ...  \
# 0  77.568156           2    0     1              0           0  ...
# 1  77.561887           1    0     0              0           1  ...
# 2  77.661063           1    0     0              0           1  ...
# 3  77.592606           1    0     0              0           0  ...
# 4  77.751625           1    1     1              1           1  ...
#
#    property_size  property_age  bathroom  facing  cup_board  floor  \
# ...

# %%
X_test_new = new_data[['type', 'lease_type', 'gym', 'lift', 'swimming_pool', 'negotiable',
                      'furnishing', 'parking', 'property_size', 'property_age', 'bathroom', 'facing', 'cup_board',
                      'floor', 'total_floor', 'water_supply', 'building_type', 'balconies']].values

# %%
predictions = regressor.predict(X_test_new)

# %%
predictions_df = pd.DataFrame({'Predicted Rent': predictions})
predictions_df.to_excel('predicted_rent_output.xlsx', index=False)
